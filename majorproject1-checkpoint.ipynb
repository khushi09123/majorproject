# %%
import time

# %%
def timemodule():
    import time
    start_time= time.time()
    seconds=0  
    print(start_time)
    while True:
        try:
            if(seconds>=5):
                print("Elapsed time: {:02d}:{:02d}:{:02d}".format(int(hours),int(minutes), int(seconds)))
                print(round(seconds))
                return ("{:02d}:{:02d}:{:02d}".format(int(hours),int(minutes), int(seconds)))
                break
        except SyntaxError:
            pass
        elapsed_time= time.time()-start_time
        hours, remainder = divmod(elapsed_time, 3600)
        minutes, seconds = divmod(remainder, 60)

# %%
def detection():
    import cv2
    import numpy as np
    import os 

    recognizer = cv2.face.LBPHFaceRecognizer_create()
    recognizer.read('C:\\Users\\Khushi\\trainer.yml')

    cascadePath = "C:\\Users\\Khushi\\haarcascade_frontalface_default.xml"
    faceCascade = cv2.CascadeClassifier(cascadePath);

    font = cv2.FONT_HERSHEY_SIMPLEX
    count=0

    # initiate id counter
    id = 0

    # names related to ids: example ==> Marcelo: id=1,  etc
    names = ['none', 'venkat','divya',]

    # Initialize and start realtime video capture
    cam = cv2.VideoCapture(0)
    cam.set(3, 640) # set video width
    cam.set(4, 480) # set video height
    start_time1 = time.time()

    # Define min window size to be recognized as a face
    minW = 0.1*cam.get(3)
    minH = 0.1*cam.get(4)

    while True:
        ret, img = cam.read()
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        faces = faceCascade.detectMultiScale( 
            gray,
            scaleFactor = 1.2,
            minNeighbors = 2,
            minSize = (int(minW), int(minH)),
           )

        for(x, y, w, h) in faces:
            cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
            id, confidence = recognizer.predict(gray[y:y+h,x:x+w])

            # If confidence is less than 100 ==> "0": perfect match 
    #         print(id)
            if confidence < 100:
                # Check if id is within the valid range of names
                if id < 15 :
                    id = 1
                elif id > 15 :
                    id = 2
                if id < len(names):
                    id = names[id]
                    current_time1 = time.time()
                    elapsed_time1 = current_time1 - start_time1
                    if elapsed_time1 >= 10:
                        cam.release()
                        cv2.destroyAllWindows()
                        return id
                else:
                    id = "unknown"

                confidence = " {0}%".format(round(100 - confidence))
            else:
                id = "unknown"
                confidence = " {0}%".format(round(100 - confidence))

            cv2.putText(
                        img, 
                        str(id), 
                        (x+5,y-5), 
                        font, 
                        1, 
                        (255,255,255), 
                        2
                       )
            cv2.putText(
                        img, 
                        str(confidence), 
                        (x+5,y+h-5), 
                        font, 
                        1, 
                        (255,255,0), 
                        1
                       )
#         print(str(id))
        cv2.imshow('camera',img) 
        k = cv2.waitKey(50) & 0xff # Press 'ESC' for exiting video
        if k == 27:
            break

    # Do a bit of cleanup
    print("\n [INFO] Exiting Program and cleanup stuff")
    cam.release()
    cv2.destroyAllWindows()

# %%
import cv2
import os
from keras.models import load_model
import numpy as np
from pygame import mixer
import time
mixer.init()
sound = mixer.Sound('C:\\Users\\Khushi\\Drowsiness detection\\alarm.wav')
face = cv2.CascadeClassifier('C:\\Users\\Khushi\\Drowsiness detection\\haar cascade files\\haarcascade_frontalface_alt.xml')
leye = cv2.CascadeClassifier('C:\\Users\\Khushi\\Drowsiness detection\\haar cascade files\\haarcascade_lefteye_2splits.xml')
reye = cv2.CascadeClassifier('C:\\Users\\Khushi\\Drowsiness detection\\haar cascade files\\haarcascade_righteye_2splits.xml')
lbl=['Close','Open']
model = load_model('C:\\Users\\Khushi\\Drowsiness detection\\models\\cnncat2.h5')
# print(model)
path = os.getcwd()
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
count=0
score=0
thicc=2
rpred=[99]
lpred=[99]
detected_name=detection()
if detected_name=='khushi':
    start_time= time.time()
while(True):
    ret, frame = cap.read()
    height,width = frame.shape[:2]
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
    left_eye = leye.detectMultiScale(gray)
    right_eye = reye.detectMultiScale(gray)
    cv2.rectangle(frame, (0,height-50) , (200,height) , (0,0,0) , thickness=cv2.FILLED )
    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y) , (x+w,y+h) , (100,100,100) , 1 )
    for (x,y,w,h) in right_eye:
        r_eye=frame[y:y+h,x:x+w]
        count=count+1
        r_eye = cv2.cvtColor(r_eye,cv2.COLOR_BGR2GRAY)
        r_eye = cv2.resize(r_eye,(24,24))
        r_eye= r_eye/255
        r_eye= r_eye.reshape(24,24,-1)
        r_eye = np.expand_dims(r_eye,axis=0)
        rpred = np.argmax(model.predict(r_eye), axis=-1)
        if(rpred[0]==1):
            lbl='Open'
        if(rpred[0]==0):
            lbl='Closed'
        break

    for (x,y,w,h) in left_eye:
        l_eye=frame[y:y+h,x:x+w]
        count=count+1
        l_eye = cv2.cvtColor(l_eye,cv2.COLOR_BGR2GRAY)
        l_eye = cv2.resize(l_eye,(24,24))
        l_eye= l_eye/255
        l_eye=l_eye.reshape(24,24,-1)
        l_eye = np.expand_dims(l_eye,axis=0)
        lpred = np.argmax(model.predict(l_eye), axis=-1)
        if(lpred[0]==1):
            lbl='Open'
        if(lpred[0]==0):
            lbl='Closed'
        break

    if(rpred[0]==0 and lpred[0]==0):
        score=score+1
        cv2.putText(frame,"Closed",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    else:
        score=score-1
        cv2.putText(frame,"Open",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    if(score<0):
        score=0
    cv2.putText(frame,'Score:'+str(score),(100,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    if(score>5):
        cv2.imwrite(os.path.join(path,'image.jpg'),frame)
        try:
            sound.play()
        except: 
            pass
        if(thicc<16):
            thicc= thicc+2
        else:
            thicc=thicc-2
            if(thicc<2):
                thicc=2
        cv2.rectangle(frame,(0,0),(width,height),(0,0,255),thicc)
    elapsed_time= time.time()-start_time
    hours, remainder = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(remainder, 60)
    seconds=round(seconds)
    if seconds>30:
        detected_name=detection()
        if detected_name=='divya':
            print("time exceeded")
            sound.play()
            time.sleep(2)
            start_time=time.time()
    cv2.imshow('frame',frame)
    elapsed_time2=time.time()-start_time
    hours, remainder = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(remainder, 60)    
    if seconds>40:
        cap.release()
        cv2.destroyAllWindows()
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5004\4192563665.py in <module>
#      86                 thicc=2
#      87         cv2.rectangle(frame,(0,0),(width,height),(0,0,255),thicc)
# ---> 88     elapsed_time= time.time()-start_time
#      89     hours, remainder = divmod(elapsed_time, 3600)
#      90     minutes, seconds = divmod(remainder, 60)
#
# NameError: name 'start_time' is not defined

# %%
x=detection()
print(x)

# %%
seconds = timemodule()
print(seconds)
# return ("{:05d}:{:05d}:{:05d}".format(int(hours),int(minutes), int(seconds)))
